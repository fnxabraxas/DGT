# %%
import pandas as pd
import numpy as np
import Parameters
import matplotlib.pylab as plt
# %matplotlib inline
print Parameters.dirname
import seaborn as sns

from Parameters import num_agents, total_games, d, barabasi_albert_m, A_s, B_s, C_s, D_s, A_d, B_d, C_d, D_d, edge_p, num_groups, p_out, graph_type

k_list = [0.01, 0.1, 1.0]
plt.subplot(2,2,1)

t_count = Parameters.total_games/Parameters.infreq_data
times = [t*Parameters.infreq_data for t in range(t_count+1)]
print times

for kappa in k_list:
    index = k_list.index(kappa) +1
    plt.subplot(2,2,index)
    if graph_type == 'BA':
        dirname = 'data/%iPlayers_%iGames_%.2fkappa_%.2fd_BA_%im_%.1fAs_%.1fBs_%.1fCs_%.1fDs_%.1fAd_%.1fBd_%.1fCd_%.1fDd/' %( num_agents, total_games, kappa, d, barabasi_albert_m , A_s, B_s, C_s, D_s, A_d, B_d, C_d, D_d)

    elif graph_type == 'Random':
        dirname = 'data/%iPlayers_%iGames_%.2fkappa_%.2fd_Random_%.3fp_%.1fAs_%.1fBs_%.1fCs_%.1fDs_%.1fAd_%.1fBd_%.1fCd_%.1fDd/' %( num_agents, total_games, kappa, d, edge_p,  A_s, B_s, C_s, D_s, A_d, B_d, C_d, D_d)

    elif graph_type == 'None':
        dirname = 'data/%iPlayers_%iGames_%.2fkappa_%.2fd_Well_mixed_%.1fAs_%.1fBs_%.1fCs_%.1fDs_%.1fAd_%.1fBd_%.1fCd_%.1fDd/' %( num_agents, total_games, kappa, d,  A_s, B_s, C_s, D_s, A_d, B_d, C_d, D_d)

    elif graph_type == 'Groups':
        dirname = 'data/%iPlayers_%iGames_%.2fkappa_%.2fd_Groups_%igroups_%.3fpout_%.1fAs_%.1fBs_%.1fCs_%.1fDs_%.1fAd_%.1fBd_%.1fCd_%.1fDd/' %( num_agents, total_games, kappa, d, num_groups, p_out,  A_s, B_s, C_s, D_s, A_d, B_d, C_d, D_d)


    time_dict = {}

    for t in times:
        fname = '0_agent_data_%i.csv' % t
        fdata = pd.read_csv(dirname+fname)
        time_dict[t] = fdata['strategies'].mean()
        #print time_dict[t]
        #timedf = pd.DataFrame(time_dict)
        
    sns.set_style('darkgrid')
    plt.scatter(time_dict.keys(), time_dict.values())
    plt.tick_params(
    axis='x',          # changes apply to the x-axis
    which='both',      # both major and minor ticks are affected
    bottom='off',      # ticks along the bottom edge are off
    top='off',         # ticks along the top edge are off
    labelbottom='off') # labels along the bottom edge are off
    plt.title('$\kappa$ = %.3f' % kappa)
    plt.xlabel('time')
    plt.ylabel('$x_c$')
plt.tight_layout()
fig = plt.gcf()
fig.set_size_inches(18.5, 10.5)
fig.savefig('Well_mixed_with_kapp.png', dpi=200)
plt.show()
# Out:
# data/200Players_10000Games_0.01kappa_0.05d_Well_mixed_0.0As_-1.0Bs_1.0Cs_0.0Ds_2.0Ad_1.0Bd_1.0Cd_0.0Dd/
# [0, 100, 200, 300, 400, 500, 600, 700, 800, 900, 1000, 1100, 1200, 1300, 1400, 1500, 1600, 1700, 1800, 1900, 2000, 2100, 2200, 2300, 2400, 2500, 2600, 2700, 2800, 2900, 3000, 3100, 3200, 3300, 3400, 3500, 3600, 3700, 3800, 3900, 4000, 4100, 4200, 4300, 4400, 4500, 4600, 4700, 4800, 4900, 5000, 5100, 5200, 5300, 5400, 5500, 5600, 5700, 5800, 5900, 6000, 6100, 6200, 6300, 6400, 6500, 6600, 6700, 6800, 6900, 7000, 7100, 7200, 7300, 7400, 7500, 7600, 7700, 7800, 7900, 8000, 8100, 8200, 8300, 8400, 8500, 8600, 8700, 8800, 8900, 9000, 9100, 9200, 9300, 9400, 9500, 9600, 9700, 9800, 9900, 10000]

# %%
import pandas as pd
import numpy as np
import Parameters
import matplotlib.pylab as plt
# %matplotlib inline
print Parameters.dirname
import seaborn as sns

from Parameters import num_agents, total_games, kappa, d, barabasi_albert_m, A_s, B_s, C_s, D_s, A_d, B_d, C_d, D_d, num_groups, p_out, graph_type

p_list = [0.1, 0.25, 0.5,0.75, 0.9]
plt.subplot(3,2,1)

t_count = Parameters.total_games/Parameters.infreq_data
times = [t*Parameters.infreq_data for t in range(t_count+1)]
print times

for edge_p in p_list:
    index = p_list.index(edge_p) +1
    plt.subplot(3,2,index)
    if graph_type == 'BA':
        dirname = 'data/%iPlayers_%iGames_%.2fkappa_%.2fd_BA_%im_%.1fAs_%.1fBs_%.1fCs_%.1fDs_%.1fAd_%.1fBd_%.1fCd_%.1fDd/' %( num_agents, total_games, kappa, d, barabasi_albert_m , A_s, B_s, C_s, D_s, A_d, B_d, C_d, D_d)

    elif graph_type == 'Random':
        dirname = 'data/%iPlayers_%iGames_%.2fkappa_%.2fd_Random_%.3fp_%.1fAs_%.1fBs_%.1fCs_%.1fDs_%.1fAd_%.1fBd_%.1fCd_%.1fDd/' %( num_agents, total_games, kappa, d, edge_p,  A_s, B_s, C_s, D_s, A_d, B_d, C_d, D_d)

    elif graph_type == 'None':
        dirname = 'data/%iPlayers_%iGames_%.2fkappa_%.2fd_Well_mixed_%.1fAs_%.1fBs_%.1fCs_%.1fDs_%.1fAd_%.1fBd_%.1fCd_%.1fDd/' %( num_agents, total_games, kappa, d,  A_s, B_s, C_s, D_s, A_d, B_d, C_d, D_d)

    elif graph_type == 'Groups':
        dirname = 'data/%iPlayers_%iGames_%.2fkappa_%.2fd_Groups_%igroups_%.3fpout_%.1fAs_%.1fBs_%.1fCs_%.1fDs_%.1fAd_%.1fBd_%.1fCd_%.1fDd/' %( num_agents, total_games, kappa, d, num_groups, p_out,  A_s, B_s, C_s, D_s, A_d, B_d, C_d, D_d)


    time_dict = {}

    for t in times:
        fname = '0_agent_data_%i.csv' % t
        fdata = pd.read_csv(dirname+fname)
        time_dict[t] = fdata['strategies']
        
        timedf = pd.DataFrame(time_dict)
        
    bp = sns.boxplot(timedf, fliersize = 0.0, linewidth = 0.25, notch = True)
    plt.tick_params(
    axis='x',          # changes apply to the x-axis
    which='both',      # both major and minor ticks are affected
    bottom='off',      # ticks along the bottom edge are off
    top='off',         # ticks along the top edge are off
    labelbottom='off') # labels along the bottom edge are off
    plt.title('edge_p = %.3f' % edge_p)
    plt.xlabel('time')
    plt.ylabel('$x_c$')
plt.tight_layout()
fig = plt.gcf()
fig.set_size_inches(18.5, 10.5)
fig.savefig('Random_with_d.png', dpi=200)
plt.show()
# Out:
# data/200Players_10000Games_1.00kappa_0.10d_Random_0.100p_0.0As_-1.0Bs_1.0Cs_0.0Ds_2.0Ad_1.0Bd_1.0Cd_0.0Dd/
# [0, 100, 200, 300, 400, 500, 600, 700, 800, 900, 1000, 1100, 1200, 1300, 1400, 1500, 1600, 1700, 1800, 1900, 2000, 2100, 2200, 2300, 2400, 2500, 2600, 2700, 2800, 2900, 3000, 3100, 3200, 3300, 3400, 3500, 3600, 3700, 3800, 3900, 4000, 4100, 4200, 4300, 4400, 4500, 4600, 4700, 4800, 4900, 5000, 5100, 5200, 5300, 5400, 5500, 5600, 5700, 5800, 5900, 6000, 6100, 6200, 6300, 6400, 6500, 6600, 6700, 6800, 6900, 7000, 7100, 7200, 7300, 7400, 7500, 7600, 7700, 7800, 7900, 8000, 8100, 8200, 8300, 8400, 8500, 8600, 8700, 8800, 8900, 9000, 9100, 9200, 9300, 9400, 9500, 9600, 9700, 9800, 9900, 10000]
# c:\users\cole\appdata\local\enthought\canopy\user\lib\site-packages\seaborn\categorical.py:2125: UserWarning: The boxplot API has been changed. Attempting to adjust your arguments for the new API (which might not work). Please update your code. See the version 0.6 release notes for more info.
#   warnings.warn(msg, UserWarning)
